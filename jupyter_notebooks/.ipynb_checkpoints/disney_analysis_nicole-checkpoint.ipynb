# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
df_disney = pd.read_csv("..\data\disney_dataset_analysis.csv")
df_disney
# Out:
# <>:4: SyntaxWarning: invalid escape sequence '\d'
# <>:4: SyntaxWarning: invalid escape sequence '\d'
# C:\Users\Nicole\AppData\Local\Temp\ipykernel_3940\701385212.py:4: SyntaxWarning: invalid escape sequence '\d'
#   df_disney = pd.read_csv("..\data\disney_dataset_analysis.csv")
#                                title  running_time       budget    box_office  \
# 0                          Pinocchio            88    2600000.0  1.640000e+08
# 1                           Fantasia           126    2280000.0  8.330000e+07
# 2                  Song of the South            94    2125000.0  6.500000e+07
# 3                         Cinderella            74    2900000.0  2.636000e+08
# 4                Alice in Wonderland            75    3000000.0  5.600000e+06
# ..                               ...           ...          ...           ...
# 155  Alice Through the Looking Glass           113  170000000.0  3.000000e+08
# 156                     Finding Dory            97  175000000.0  1.029000e+09
# 157                          The BFG           117  140000000.0  1.952000e+08
# 158                   Queen of Katwe           124   15000000.0  1.040000e+07
# 159                            Moana           107  150000000.0  6.908000e+08
#
#     release_date  imdb  metascore  rotten_tomatoes  \
# 0     1940-02-07   7.4         99              100
# 1     1940-11-13   7.8         96               95
# 2     1946-11-12   7.1         54               50
# 3     1950-02-15   6.9         67               84
# 4     1951-07-26   6.4         53               51
# ..           ...   ...        ...              ...
# 155   2016-05-10   6.2         34               29
# 156   2016-06-08   7.3         77               94
# 157   2016-05-14   6.4         66               74
# 158   2016-09-10   7.4         73               93
# 159   2016-11-14   7.6         81               95
#
#                                            directed_by      genre  \
# 0    ['Ben Sharpsteen', 'Hamilton Luske', 'Bill Rob...  Adventure
# 1    ['Samuel Armstrong', 'James Algar', 'Bill Robe...    Musical
# 2    ['Live action ', 'Harve Foster', 'Animation ',...  Adventure
# 3    ['Clyde Geronimi', 'Hamilton Luske', 'Wilfred ...      Drama
# 4    ['Clyde Geronimi', 'Wilfred Jackson', 'Hamilto...  Adventure
# ..                                                 ...        ...
# 155                                        James Bobin  Adventure
# 156                                     Andrew Stanton  Adventure
# 157                                   Steven Spielberg  Adventure
# 158                                          Mira Nair      Drama
# 159                    ['Ron Clements', 'John Musker']  Adventure
#
#      total_gross  inflation_adjusted_gross  year  \
# 0     84300000.0                2188229052  1940
# 1     83320000.0                2187090808  1940
# 2     65000000.0                1078510579  1946
# 3     85000000.0                 920608730  1950
# 4    334191110.0                 357063499  1951
# ..           ...                       ...   ...
# 155   77042381.0                  77042381  2016
# 156  486295561.0                 486295561  2016
# 157   55483770.0                  55483770  2016
# 158    8874389.0                   8874389  2016
# 159  246082029.0                 246082029  2016
#
#                                             book_title           book_writer
# 0                          The Adventures of Pinocchio         Carlo Collodi
# 1                                   Not based on books             Not found
# 2                                          Uncle Remus  Joel Chandler Harris
# 3                                           Cinderella      Charles Perrault
# 4    Alice's Adventures in Wonderland and Through t...         Lewis Carroll
# ..                                                 ...                   ...
# 155                                         Characters         Lewis Carroll
# 156                                 Not based on books             Not found
# 157                                            The BFG            Roald Dahl
# 158                                 The Queen of Katwe          Tim Crothers
# 159                                 Not based on books             Not found
#
# [160 rows x 15 columns]

# %%
correlation = df_disney ['imdb'].corr(df_disney['running_time'])
print (correlation)
# Out:
# 0.06946057630496554

# %%
sns.lmplot(x='running_time', y='imdb', data=df_disney, aspect=2, height=6)
plt.title('Correlation between IMDb Ratings and Running Time')
plt.xlabel('Running Time (minutes)')
plt.ylabel('IMDb Rating')
plt.show()

# %%
#relationship is very weak between running time and ratings
#slight upward slope of the regression line - a slight tendency for longer movies to receive higher IMDb ratings
#wide spread of points - other factors are likely more important in determining IMDb ratings than just the length of the movie.

# %%
# Box plot for IMDb ratings
plt.figure(figsize=(8, 6))
sns.boxplot(y='imdb', data=df_disney)
plt.title('Box Plot of IMDb Ratings')
plt.ylabel('IMDb Rating')
plt.show()

# %%
# Box plot for Running Time
plt.figure(figsize=(8, 6))
sns.boxplot(y='running_time', data=df_disney)
plt.title('Box Plot of Running Time')
plt.ylabel('Running Time (minutes)')
plt.show()

# %%
def categorize_rating(rating):
    if rating < 5:
        return 'poor rating'
    elif 5 <= rating <= 7:
        return 'moderate rating'
    else:
        return 'good rating'
df_disney['rating_category'] = df_disney['imdb'].apply(categorize_rating)

(df_disney)
# Out:
#                                title  running_time       budget    box_office  \
# 0                          Pinocchio            88    2600000.0  1.640000e+08
# 1                           Fantasia           126    2280000.0  8.330000e+07
# 2                  Song of the South            94    2125000.0  6.500000e+07
# 3                         Cinderella            74    2900000.0  2.636000e+08
# 4                Alice in Wonderland            75    3000000.0  5.600000e+06
# ..                               ...           ...          ...           ...
# 155  Alice Through the Looking Glass           113  170000000.0  3.000000e+08
# 156                     Finding Dory            97  175000000.0  1.029000e+09
# 157                          The BFG           117  140000000.0  1.952000e+08
# 158                   Queen of Katwe           124   15000000.0  1.040000e+07
# 159                            Moana           107  150000000.0  6.908000e+08
#
#     release_date  imdb  metascore  rotten_tomatoes  \
# 0     1940-02-07   7.4         99              100
# 1     1940-11-13   7.8         96               95
# 2     1946-11-12   7.1         54               50
# 3     1950-02-15   6.9         67               84
# 4     1951-07-26   6.4         53               51
# ..           ...   ...        ...              ...
# 155   2016-05-10   6.2         34               29
# 156   2016-06-08   7.3         77               94
# 157   2016-05-14   6.4         66               74
# 158   2016-09-10   7.4         73               93
# 159   2016-11-14   7.6         81               95
#
#                                            directed_by      genre  \
# 0    ['Ben Sharpsteen', 'Hamilton Luske', 'Bill Rob...  Adventure
# 1    ['Samuel Armstrong', 'James Algar', 'Bill Robe...    Musical
# 2    ['Live action ', 'Harve Foster', 'Animation ',...  Adventure
# 3    ['Clyde Geronimi', 'Hamilton Luske', 'Wilfred ...      Drama
# 4    ['Clyde Geronimi', 'Wilfred Jackson', 'Hamilto...  Adventure
# ..                                                 ...        ...
# 155                                        James Bobin  Adventure
# 156                                     Andrew Stanton  Adventure
# 157                                   Steven Spielberg  Adventure
# 158                                          Mira Nair      Drama
# 159                    ['Ron Clements', 'John Musker']  Adventure
#
#      total_gross  inflation_adjusted_gross  year  \
# 0     84300000.0                2188229052  1940
# 1     83320000.0                2187090808  1940
# 2     65000000.0                1078510579  1946
# 3     85000000.0                 920608730  1950
# 4    334191110.0                 357063499  1951
# ..           ...                       ...   ...
# 155   77042381.0                  77042381  2016
# 156  486295561.0                 486295561  2016
# 157   55483770.0                  55483770  2016
# 158    8874389.0                   8874389  2016
# 159  246082029.0                 246082029  2016
#
#                                             book_title           book_writer  \
# 0                          The Adventures of Pinocchio         Carlo Collodi
# 1                                   Not based on books             Not found
# 2                                          Uncle Remus  Joel Chandler Harris
# 3                                           Cinderella      Charles Perrault
# 4    Alice's Adventures in Wonderland and Through t...         Lewis Carroll
# ..                                                 ...                   ...
# 155                                         Characters         Lewis Carroll
# 156                                 Not based on books             Not found
# 157                                            The BFG            Roald Dahl
# 158                                 The Queen of Katwe          Tim Crothers
# 159                                 Not based on books             Not found
#
#      rating_category
# 0        good rating
# 1        good rating
# 2        good rating
# 3    moderate rating
# 4    moderate rating
# ..               ...
# 155  moderate rating
# 156      good rating
# 157  moderate rating
# 158      good rating
# 159      good rating
#
# [160 rows x 16 columns]

# %%
def categorize_running_time(runtime):
    if runtime < 120:
        return 'below 120 minutes'
    else:
        return '120 minutes or more'
df_disney['running_time_category'] = df_disney['running_time'].apply(categorize_running_time)
# Out:
#                                title  running_time       budget    box_office  \
# 0                          Pinocchio            88    2600000.0  1.640000e+08
# 1                           Fantasia           126    2280000.0  8.330000e+07
# 2                  Song of the South            94    2125000.0  6.500000e+07
# 3                         Cinderella            74    2900000.0  2.636000e+08
# 4                Alice in Wonderland            75    3000000.0  5.600000e+06
# ..                               ...           ...          ...           ...
# 155  Alice Through the Looking Glass           113  170000000.0  3.000000e+08
# 156                     Finding Dory            97  175000000.0  1.029000e+09
# 157                          The BFG           117  140000000.0  1.952000e+08
# 158                   Queen of Katwe           124   15000000.0  1.040000e+07
# 159                            Moana           107  150000000.0  6.908000e+08
#
#     release_date  imdb  metascore  rotten_tomatoes  \
# 0     1940-02-07   7.4         99              100
# 1     1940-11-13   7.8         96               95
# 2     1946-11-12   7.1         54               50
# 3     1950-02-15   6.9         67               84
# 4     1951-07-26   6.4         53               51
# ..           ...   ...        ...              ...
# 155   2016-05-10   6.2         34               29
# 156   2016-06-08   7.3         77               94
# 157   2016-05-14   6.4         66               74
# 158   2016-09-10   7.4         73               93
# 159   2016-11-14   7.6         81               95
#
#                                            directed_by      genre  \
# 0    ['Ben Sharpsteen', 'Hamilton Luske', 'Bill Rob...  Adventure
# 1    ['Samuel Armstrong', 'James Algar', 'Bill Robe...    Musical
# 2    ['Live action ', 'Harve Foster', 'Animation ',...  Adventure
# 3    ['Clyde Geronimi', 'Hamilton Luske', 'Wilfred ...      Drama
# 4    ['Clyde Geronimi', 'Wilfred Jackson', 'Hamilto...  Adventure
# ..                                                 ...        ...
# 155                                        James Bobin  Adventure
# 156                                     Andrew Stanton  Adventure
# 157                                   Steven Spielberg  Adventure
# 158                                          Mira Nair      Drama
# 159                    ['Ron Clements', 'John Musker']  Adventure
#
#      total_gross  inflation_adjusted_gross  year  \
# 0     84300000.0                2188229052  1940
# 1     83320000.0                2187090808  1940
# 2     65000000.0                1078510579  1946
# 3     85000000.0                 920608730  1950
# 4    334191110.0                 357063499  1951
# ..           ...                       ...   ...
# 155   77042381.0                  77042381  2016
# 156  486295561.0                 486295561  2016
# 157   55483770.0                  55483770  2016
# 158    8874389.0                   8874389  2016
# 159  246082029.0                 246082029  2016
#
#                                             book_title           book_writer  \
# 0                          The Adventures of Pinocchio         Carlo Collodi
# 1                                   Not based on books             Not found
# 2                                          Uncle Remus  Joel Chandler Harris
# 3                                           Cinderella      Charles Perrault
# 4    Alice's Adventures in Wonderland and Through t...         Lewis Carroll
# ..                                                 ...                   ...
# 155                                         Characters         Lewis Carroll
# 156                                 Not based on books             Not found
# 157                                            The BFG            Roald Dahl
# 158                                 The Queen of Katwe          Tim Crothers
# 159                                 Not based on books             Not found
#
#      rating_category running_time_category
# 0        good rating     below 120 minutes
# 1        good rating   120 minutes or more
# 2        good rating     below 120 minutes
# 3    moderate rating     below 120 minutes
# 4    moderate rating     below 120 minutes
# ..               ...                   ...
# 155  moderate rating     below 120 minutes
# 156      good rating     below 120 minutes
# 157  moderate rating     below 120 minutes
# 158      good rating   120 minutes or more
# 159      good rating     below 120 minutes
#
# [160 rows x 17 columns]

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='running_time_category', y='imdb', data=df_disney)
plt.title('Box Plot of IMDb Ratings by Running Time Category')
plt.xlabel('Running Time Category')
plt.ylabel('IMDb Rating')
plt.show()

# %%
#The plot suggests that while longer movies generally receive more consistent and slightly higher ratings, 
# shorter movies have a more diverse range of ratings, including some lower-rated films.
# longer movies tend to be more favorably received or possibly that they are more consistent in quality, 
# while shorter movies might vary more widely in audience reception.

# %%
df_below_120 = df_disney[df_disney['running_time'] < 120]

# Plot the KDE plot for IMDb ratings of movies below 120 minutes
plt.figure(figsize=(10, 6))
sns.kdeplot(df_below_120['imdb'], shade=True, color="blue")
plt.title('KDE Plot of IMDb Ratings for Movies with Running Time Below 120 Minutes')
plt.xlabel('IMDb Rating')
plt.ylabel('Density')
plt.show()
# Out:
# C:\Users\Nicole\AppData\Local\Temp\ipykernel_3940\2990312725.py:5: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df_below_120['imdb'], shade=True, color="blue")

# %%
df_disney['based_on_book'] = df_disney['book_title'].apply(lambda x: 'Yes' if x != 'Not based on books' else 'No')
df_disney
# Out:
#                                title  running_time       budget    box_office  \
# 0                          Pinocchio            88    2600000.0  1.640000e+08
# 1                           Fantasia           126    2280000.0  8.330000e+07
# 2                  Song of the South            94    2125000.0  6.500000e+07
# 3                         Cinderella            74    2900000.0  2.636000e+08
# 4                Alice in Wonderland            75    3000000.0  5.600000e+06
# ..                               ...           ...          ...           ...
# 155  Alice Through the Looking Glass           113  170000000.0  3.000000e+08
# 156                     Finding Dory            97  175000000.0  1.029000e+09
# 157                          The BFG           117  140000000.0  1.952000e+08
# 158                   Queen of Katwe           124   15000000.0  1.040000e+07
# 159                            Moana           107  150000000.0  6.908000e+08
#
#     release_date  imdb  metascore  rotten_tomatoes  \
# 0     1940-02-07   7.4         99              100
# 1     1940-11-13   7.8         96               95
# 2     1946-11-12   7.1         54               50
# 3     1950-02-15   6.9         67               84
# 4     1951-07-26   6.4         53               51
# ..           ...   ...        ...              ...
# 155   2016-05-10   6.2         34               29
# 156   2016-06-08   7.3         77               94
# 157   2016-05-14   6.4         66               74
# 158   2016-09-10   7.4         73               93
# 159   2016-11-14   7.6         81               95
#
#                                            directed_by      genre  \
# 0    ['Ben Sharpsteen', 'Hamilton Luske', 'Bill Rob...  Adventure
# 1    ['Samuel Armstrong', 'James Algar', 'Bill Robe...    Musical
# 2    ['Live action ', 'Harve Foster', 'Animation ',...  Adventure
# 3    ['Clyde Geronimi', 'Hamilton Luske', 'Wilfred ...      Drama
# 4    ['Clyde Geronimi', 'Wilfred Jackson', 'Hamilto...  Adventure
# ..                                                 ...        ...
# 155                                        James Bobin  Adventure
# 156                                     Andrew Stanton  Adventure
# 157                                   Steven Spielberg  Adventure
# 158                                          Mira Nair      Drama
# 159                    ['Ron Clements', 'John Musker']  Adventure
#
#      total_gross  inflation_adjusted_gross  year  \
# 0     84300000.0                2188229052  1940
# 1     83320000.0                2187090808  1940
# 2     65000000.0                1078510579  1946
# 3     85000000.0                 920608730  1950
# 4    334191110.0                 357063499  1951
# ..           ...                       ...   ...
# 155   77042381.0                  77042381  2016
# 156  486295561.0                 486295561  2016
# 157   55483770.0                  55483770  2016
# 158    8874389.0                   8874389  2016
# 159  246082029.0                 246082029  2016
#
#                                             book_title           book_writer  \
# 0                          The Adventures of Pinocchio         Carlo Collodi
# 1                                   Not based on books             Not found
# 2                                          Uncle Remus  Joel Chandler Harris
# 3                                           Cinderella      Charles Perrault
# 4    Alice's Adventures in Wonderland and Through t...         Lewis Carroll
# ..                                                 ...                   ...
# 155                                         Characters         Lewis Carroll
# 156                                 Not based on books             Not found
# 157                                            The BFG            Roald Dahl
# 158                                 The Queen of Katwe          Tim Crothers
# 159                                 Not based on books             Not found
#
#      rating_category running_time_category based_on_book
# 0        good rating     below 120 minutes           Yes
# 1        good rating   120 minutes or more            No
# 2        good rating     below 120 minutes           Yes
# 3    moderate rating     below 120 minutes           Yes
# 4    moderate rating     below 120 minutes           Yes
# ..               ...                   ...           ...
# 155  moderate rating     below 120 minutes           Yes
# 156      good rating     below 120 minutes            No
# 157  moderate rating     below 120 minutes           Yes
# 158      good rating   120 minutes or more           Yes
# 159      good rating     below 120 minutes            No
#
# [160 rows x 18 columns]

# %%
df_disney['based_on_book_numeric'] = df_disney['based_on_book'].map({'Yes': 1, 'No': 0})

# %%
df_disney['based_on_book_numeric'].describe().round(2)
# Out:
# count    160.00
# mean       0.55
# std        0.50
# min        0.00
# 25%        0.00
# 50%        1.00
# 75%        1.00
# max        1.00
# Name: based_on_book_numeric, dtype: float64

# %%
df_disney['imdb'].describe().round()
# Out:
# count    160.0
# mean       7.0
# std        1.0
# min        4.0
# 25%        6.0
# 50%        7.0
# 75%        7.0
# max        8.0
# Name: imdb, dtype: float64

# %%
plt.figure(figsize=(10, 6))
sns.violinplot(x='based_on_book', y='imdb', data=df_disney)
plt.title('Violin Plot of IMDb Ratings: Based on Books vs. Not Based on Books')
plt.xlabel('Based on Book')
plt.ylabel('IMDb Rating')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='based_on_book', y='imdb', data=df_disney)
plt.title('Box Plot of IMDb Ratings: Based on Books vs. Not Based on Books')
plt.xlabel('Based on Book')
plt.ylabel('IMDb Rating')
plt.show()

# %%
#Bar graph
sns.barplot(x='based_on_book', y='imdb', data=df_disney)
plt.title('Bar Plot of of imdb Ratings and Books')
plt.show()

# %%
df_hypo3 = df_disney.groupby('based_on_book')['imdb'].mean().reset_index()
df_hypo3.columns = ['Based on Book', 'Average IMDb Rating']
display(df_hypo3)
# Out:
#   Based on Book  Average IMDb Rating
# 0            No             6.688889
# 1           Yes             6.482955

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x='Based on Book', y='Average IMDb Rating', data=df_hypo3, palette='muted')
plt.title('Average IMDb Ratings: Based on Books vs. Not Based on Books')
plt.xlabel('Based on Book')
plt.ylabel('Average IMDb Rating')
plt.ylim(df_hypo3['Average IMDb Rating'].min() - 0.5, df_hypo3['Average IMDb Rating'].max() + 0.5)  # Adjust y-axis limits
plt.grid(True, linestyle='--', alpha=0.6)
plt.show()
# Out:
# C:\Users\Nicole\AppData\Local\Temp\ipykernel_3940\1047823679.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Based on Book', y='Average IMDb Rating', data=df_hypo3, palette='muted')

# %%
df_hypo3a = df_disney.groupby('based_on_book')['rotten_tomatoes'].mean().reset_index()
df_hypo3a.columns = ['Based on Book', 'Average Rotten Tomatoes Rating']
display(df_hypo3a)
# Out:
#   Based on Book  Average Rotten Tomatoes Rating
# 0            No                       63.291667
# 1           Yes                       61.090909

# %%
df_books = df_disney.groupby(['based_on_book', 'rating_category']).size().reset_index(name='count')

# %%
plt.figure(figsize=(12, 8))
sns.barplot(x='based_on_book', y='count', hue='rating_category', data=df_books, palette='deep')
plt.title('Comparison of Rating Categories: Based on Books vs. Not Based on Books')
plt.xlabel('Based on Book')
plt.ylabel('Count')
plt.legend(title='imdb Rating Category')
plt.grid(True, linestyle='--', alpha=0.6)
plt.show()
